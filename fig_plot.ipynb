# %% [markdown]
# ## fig2

# %%
###### import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import matplotlib.ticker as ticker

import xlrd 

import numpy as np
import pandas as pd
from pdf2image import convert_from_path

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

col_width = 3.375*2 # inch
fs = np.array([10,7,5.5])*2

# %%
workbook = xlrd.open_workbook('./fig2_EE.xls')

worksheet = workbook.sheet_by_name("PBC")    
offset = -1    
cols = []
for i, row in enumerate(range(worksheet.ncols)):
    if i <= offset:
        continue
    c = []
    for j, row in enumerate(range(worksheet.nrows)):
        c.append(worksheet.cell_value(j, i))
    cols.append(c)  
for col in cols:
    u = 1
    for j in range(len(col)):
        if '' in col: 
            col.remove('') 
        if '--' in col: 
            col.remove('--') 
PBC=np.mat(cols)

worksheet = workbook.sheet_by_name("OBC")    
offset = -1    
cols = []
for i, row in enumerate(range(worksheet.ncols)):
    if i <= offset:
        continue
    c = []
    for j, row in enumerate(range(worksheet.nrows)):
        c.append(worksheet.cell_value(j, i))
    cols.append(c)  
for col in cols:
    u = 1
    for j in range(len(col)):
        if '' in col: 
            col.remove('') 
        if '--' in col: 
            col.remove('--') 
OBC=np.mat(cols)

worksheet = workbook.sheet_by_name("EE")    
offset = -1    
cols = []
for i, row in enumerate(range(worksheet.ncols)):
    if i <= offset:
        continue
    c = []
    for j, row in enumerate(range(worksheet.nrows)):
        c.append(worksheet.cell_value(j, i))
    cols.append(c)  
for col in cols:
    u = 1
    for j in range(len(col)):
        if '' in col: 
            col.remove('') 
        if '--' in col: 
            col.remove('--') 
top=np.mat(cols)
worksheet = workbook.sheet_by_name("IM")    
offset = -1    
cols = []
for i, row in enumerate(range(worksheet.ncols)):
    if i <= offset:
        continue
    c = []
    for j, row in enumerate(range(worksheet.nrows)):
        c.append(worksheet.cell_value(j, i))
    cols.append(c)  
for col in cols:
    u = 1
    for j in range(len(col)):
        if '' in col: 
            col.remove('') 
        if '--' in col: 
            col.remove('--') 
IM_PBC=np.mat(cols)

worksheet = workbook.sheet_by_name("subsystem EE")    
offset = -1    
cols = []
for i, row in enumerate(range(worksheet.ncols)):
    if i <= offset:
        continue
    c = []
    for j, row in enumerate(range(worksheet.nrows)):
        c.append(worksheet.cell_value(j, i))
    cols.append(c)  
for col in cols:
    u = 1
    for j in range(len(col)):
        if '' in col: 
            col.remove('') 
        if '--' in col: 
            col.remove('--') 
CFT=cols


#c/3*log(14/3.14*sin(3.14*x/14))+b
L=[20,14,12,10,8]
c=[1.048,1.064,1.073,1.084,1.102]
b=[0.7005,0.6995,0.6996,0.7004,0.703]
fcl=["#B8D5E2",'#E0B8B8',"#D9D9D9","#BCE5A8"]
ecl=['#096A94','#8A1A1C',"#636363","#31711B"]

# %%
plt.style.use(['science'])
plt.rcParams.update({
    "text.usetex": False,
    "font.family": "sans-serif",# specify font family here
    "font.sans-serif": "Arial",
    "mathtext.fontset":"stixsans",
    "font.size":11,
    "savefig.bbox": "standard",
    'xtick.top': False,
    'ytick.right': False,
    'xtick.direction':'in',
    'ytick.direction':'out',
    }) 




fig = plt.figure(figsize=[col_width*1,col_width*1.25],
                 facecolor='w')
fig.text(0.02, 0.97, r'a', size=fs[0])
fig.text(0.51, 0.97, r'b', size=fs[0])
fig.text(0.02, 0.65, r'c', size=fs[0])
fig.text(0.51, 0.65, r'd', size=fs[0])
fig.text(0.02, 0.33, r'e', size=fs[0])
fig.text(0.51, 0.33, r'f', size=fs[0])


plt.rcParams.update({
    "text.usetex": False,
    "font.family": "sans-serif",# specify font family here
    "font.sans-serif": "Helvetica Neue",
    "mathtext.fontset":"stixsans",
    "font.size":11,
    "savefig.bbox": "standard",
    'xtick.top': False,
    'ytick.right': False,
    'xtick.direction':'in',
    'ytick.direction':'out',
    }) 

ax0 = fig.add_axes([0.12,0.72 ,0.33,0.256])
ax00= fig.add_axes([0.61,0.72 ,0.33,0.256])
ax1 = fig.add_axes([0.12,0.4, 0.33,0.256])
ax2 = fig.add_axes([0.61,0.4, 0.33,0.256])
ax3 = fig.add_axes([0.12,0.08, 0.33,0.256])
ax4 = fig.add_axes([0.61,0.08, 0.33,0.256])

ax20 = fig.add_axes([0.76,0.77, 0.15,0.08])
y=[-0.03687,-0.1474,-0.2836,-0.3955,-0.4363,-0.4025,-0.3264,-0.2416,-0.1662,-0.106,-0.06041,-0.02684,-0.002522]
err=[0.053165,0.05365,0.03245,0.00465,0.00905,0.00325,0.0226,0.0408,0.05185,0.056,0.055295,0.05178,0.046844]
#ax3.errorbar(np.linspace(0.6,1.8,13),-np.array(y),yerr=np.array(err)/2,fmt='D-',color='#3C658D',
#             mec='#3C658D',mfc='#3C658D',mew=0.5,ms=7,alpha=0.8,lw=1.5,elinewidth=1.5)
ax20.plot(np.linspace(0.6,1.8,13),-np.array(y),'-',color=ecl[1],alpha=0.5,lw=1)
ax20.plot(np.linspace(0.6,1.8,13),-np.array(y),'.',mec=ecl[1],mfc=ecl[1],mew=1.0,ms=6,alpha=0.7,lw=1.5)
ax20.set_xscale('log')
ax20.yaxis.set_major_locator(MultipleLocator(0.2))
ax20.yaxis.set_minor_locator(MultipleLocator(0.1))
ax20.set_xlim([0.54,1.85])
ax20.set_ylim([-0.08,0.55])
ax20.set_xlabel(r'$J_1/J_0$ ', fontsize=fs[1],labelpad=0)
ax20.set_ylabel(r'$\gamma$',fontsize=fs[1],labelpad=0)
ax20.set_xticks([0.6,1.0,1.8])
ax20.set_xticklabels([0.6,1.0,1.8])
ax20.tick_params(axis='both', which='major', labelsize=fs[2],length=5,width=1)
ax20.tick_params(axis='both', which='minor', labelsize=fs[2],length=3,width=1)

ms=10
mew=0.5
lw=1
color0='#891A1C'


ax0.plot(PBC[:,0],PBC[:,6],'-', lw=2,color=ecl[0], label=r'$L=14$', alpha=0.5)
ax0.plot(PBC[:,0],PBC[:,6],'o', color=color0,mfc=fcl[0],mec=ecl[0],mew=1.0, ms=8, label=r'$L=14$', alpha=1.0)

ax0.xaxis.set_major_locator(MultipleLocator(1.0))
ax0.xaxis.set_minor_locator(MultipleLocator(0.2))
ax0.yaxis.set_major_locator(MultipleLocator(1.0))
ax0.yaxis.set_minor_locator(MultipleLocator(0.5))
ax0.set_xlim([-0.1,2.1])
ax0.set_ylim([4.3,7.7])
ax0.set_xlabel(r'$J_1/J_0$ ', fontsize=fs[1])
ax0.set_ylabel(r'$S_{half}$',fontsize=fs[1])
ax0.tick_params(axis='both', which='major', labelsize=fs[2],length=5,width=1)
ax0.tick_params(axis='both', which='minor', labelsize=fs[2],length=3,width=1)
ax0.spines['top'].set_linewidth(1)
ax0.spines['bottom'].set_linewidth(1)
ax0.spines['left'].set_linewidth(1)
ax0.spines['right'].set_linewidth(1)


Llist=np.linspace(4,14,6)
llist=np.linspace(0,15,100)
alpha=[0.3466,0.3584,0.3876,0.4386,0.5065,0.5405,0.5164,0.4775,0.4467,0.4251,0.4099]
gamma=[-2.172e-15,0.02767,0.04949,-0.03687, -0.2836,-0.4363,-0.3264,-0.1662,-0.06041,-0.002522,0.0272]
gammal=[-1.189e-14, 0.01095,0.0182,-0.1432,-0.3485,-0.4544,-0.3716,-0.2699,-0.171,-0.09621,-0.04487]
gammah=[6.496e-14,0.04439,0.08077,0.06944,-0.2186,-0.4183,-0.2813,-0.06255,0.05016,0.09116,0.09926]
ax00.plot(llist,llist*alpha[0]+gamma[0],  '-',color=ecl[0], lw=1.5,  alpha=0.5)
ax00.plot(llist,llist*alpha[5]+gamma[5],  '-',color=ecl[1], lw=1.5,  alpha=0.5)
ax00.plot(llist,llist*alpha[10]+gamma[10],'-',color=ecl[2], lw=1.5,  alpha=0.5)
ax00.plot(Llist,np.array(PBC[0,1:])[0],  'D', lw=1.0,mfc=fcl[0],mec=ecl[0],mew=0.5,  ms=7, label=r'$J_1/J_0=0$', alpha=1.0)
ax00.plot(Llist,np.array(PBC[5,1:])[0],  'D', lw=1.0,mfc=fcl[1],mec=ecl[1],mew=0.5,  ms=7, label=r'$J_1/J_0=1$', alpha=1.0)
ax00.plot(Llist,np.array(PBC[10,1:])[0], 'D', lw=1.0,mfc=fcl[2],mec=ecl[2],mew=0.5,  ms=7, label=r'$J_1/J_0=2$', alpha=1.0)
ax00.xaxis.set_major_locator(MultipleLocator(4))
ax00.xaxis.set_minor_locator(MultipleLocator(2))
ax00.yaxis.set_major_locator(MultipleLocator(2))
ax00.yaxis.set_minor_locator(MultipleLocator(1))
ax00.set_xlim([0,15])
ax00.set_ylim([-1.0,7.5])
ax00.set_xlabel(r'$L$ ', fontsize=fs[1])
ax00.set_ylabel(r'$S_{half}$',fontsize=fs[1])
ax00.tick_params(axis='both', which='major', labelsize=fs[2],length=5,width=1)
ax00.tick_params(axis='both', which='minor', labelsize=fs[2],length=3,width=1)
ax00.legend(fontsize=fs[2],ncol=1,handletextpad=0.1,frameon=False)
ax00.spines['top'].set_linewidth(1)
ax00.spines['bottom'].set_linewidth(1)
ax00.spines['left'].set_linewidth(1)
ax00.spines['right'].set_linewidth(1)


color=['#096A93','#891A1C','#888888']
d=np.linspace(1,7,7)
J=np.linspace(0,2,11)
xx=np.linspace(0.99,8.3,100)
yy=0.39*xx**(-1.47)+0.06
yy1=0.5043*xx**(-3.108)+0.002903
yy2=0.693147*xx**(-10.27)-9.5e-5


ax1.plot(xx,yy2,'-', lw=1.5,color=ecl[0], alpha=0.5,zorder=2)
ax1.plot(xx,yy,'-',  lw=1.5,color=ecl[1], alpha=0.5,zorder=2)
ax1.plot(xx,yy1,'-', lw=1.5,color=ecl[2], alpha=0.5,zorder=2)
ax1.plot(d,IM_PBC[:,0 ], 'o', lw=1.0,mfc=fcl[0],mec=ecl[0],mew=0.5,  ms=8, label=r'$J_1/J_0=0$', alpha=1.0)
ax1.plot(d,IM_PBC[:,1 ], 'o', lw=1.0,mfc=fcl[1],mec=ecl[1],mew=0.5,  ms=8, label=r'$J_1/J_0=1$', alpha=1.0)
ax1.plot(d,IM_PBC[:,2 ], 'o', lw=1.0,mfc=fcl[2],mec=ecl[2],mew=0.5,  ms=8, label=r'$J_1/J_0=2$', alpha=1.0)
ax1.set_xlim([0.7,7.3])
ax1.set_ylim([-0.05,0.9])
ax1.xaxis.set_major_locator(MultipleLocator(2))
ax1.xaxis.set_minor_locator(MultipleLocator(1))
ax1.yaxis.set_major_locator(MultipleLocator(0.2))
ax1.yaxis.set_minor_locator(MultipleLocator(0.1))
ax1.set_xlabel(r'$d$',fontsize=fs[1])
ax1.set_ylabel(r'$I_m(d)$',fontsize=fs[1])
ax1.tick_params(axis='both', which='major', labelsize=fs[2],length=5,width=1)
ax1.tick_params(axis='both', which='minor', labelsize=fs[2],length=3,width=1)
ax1.legend(loc=[0.55,0.62],fontsize=fs[2],ncol=1,handletextpad=0.1,frameon=False)
ax1.spines['top'].set_linewidth(1)
ax1.spines['bottom'].set_linewidth(1)
ax1.spines['left'].set_linewidth(1)
ax1.spines['right'].set_linewidth(1)



jlist=np.linspace(0,2,11)
a=[-6.505906924303417e-14,0.037952705414737276,0.13078497986399684,0.23471455224699045,0.31364312230916847,
0.3465735902799003,0.3228034614264168,0.28444817158509217,0.24649053428562162,0.21278963399347228,0.18403210358418387]
b=[-1.8007422247892886e-12,0.01606492547736138,0.0791192696887717,0.1962330533725729,0.31580592777072414,
0.36319501964656586,0.3370889142045581,0.2818018504856843,0.22686986350848448,0.18170045750694053,0.14676232620653673]
c=[-3.154654315551397e-11,0.0014675936314703097,0.02104665991173227,0.1042668776798088,0.2771740734676875,
0.3800698940343765,0.3061445599059689,0.19693984792590324,0.12185244417467,0.07725473427340046,0.05092217112369002]
ax2.plot(jlist,a,'-',color=ecl[0], lw=1.5,  alpha=0.8)
ax2.plot(jlist,b,'-',color=ecl[2], lw=1.5,  alpha=0.8)
ax2.plot(jlist,c,'-',color=ecl[1], lw=1.5,  alpha=0.8)

ax2.plot(jlist,a,  'D', lw=1.0,  mfc=fcl[0],mec=ecl[0], ms=7,mew=0.5,  label=r'$L=4$', alpha=1.0)
ax2.plot(jlist,b,  'D', lw=1.0,  mfc=fcl[2],mec=ecl[2], ms=7,mew=0.5,  label=r'$L=8$', alpha=1.0)
ax2.plot(jlist,c,  'D', lw=1.0,  mfc=fcl[1],mec=ecl[1], ms=7,mew=0.5,  label=r'$L=12$', alpha=1.0)

ax2.xaxis.set_major_locator(MultipleLocator(0.4))
ax2.xaxis.set_minor_locator(MultipleLocator(0.2))
ax2.yaxis.set_major_locator(MultipleLocator(0.2))
ax2.yaxis.set_minor_locator(MultipleLocator(0.1))

ax2.set_ylim([-0.02,0.54])
ax2.set_xlabel(r'$J_1/J_0$ ', fontsize=fs[1])
ax2.set_ylabel(r'$I_t\ \left(A:C\ |\ B\right)$',fontsize=fs[1])
ax2.tick_params(axis='both', which='major', labelsize=fs[2])
ax2.tick_params(axis='both', which='major', labelsize=fs[2],width=1,length=5)
ax2.tick_params(axis='both', which='minor', labelsize=fs[2],width=1,length=3)
ax2.set_facecolor("none") 
ax2.legend(loc=[0.62,0.65],fontsize=fs[2],handletextpad=0.1,frameon=False)
ax2.spines['top'].set_linewidth(1)
ax2.spines['bottom'].set_linewidth(1)
ax2.spines['left'].set_linewidth(1)
ax2.spines['right'].set_linewidth(1)



a=[1.8429702208777599e-13,0.07061423687341939,0.16717342487010622,0.23590761846401798,0.27052006818034857,0.27968776167902165,
0.27352097900379335,0.25943162185879387,0.24198564894051267,0.22373810344478118,0.206013238120335]
b=[3.842027502093666e-12,0.01498454687650086,0.06463516956185192,0.14179823027392796,0.21221714290096505,0.2427842025196547,
0.23438727541781557,0.20690706766699485,0.17563266562056157,0.14722628097021095,0.12344687582651592]
c=[6.452804957035596e-11,0.0015852755050446143,0.02082350628565932,0.08604940670481687,0.18658829481462247,0.23475506326941042,
0.20082248454170237,0.1437950922002844,0.09789877410661074,0.06678355766671684,0.04646184628483929]
ax3.plot(jlist,a,'-',color=ecl[0], lw=1.5,  alpha=0.8)
ax3.plot(jlist,b,'-',color=ecl[2], lw=1.5,  alpha=0.8)
ax3.plot(jlist,c,'-',color=ecl[1], lw=1.5,  alpha=0.8)
ax3.plot(jlist,a,  'o', lw=1.0,  mfc=fcl[0],mec=ecl[0], ms=8,mew=0.5,  label=r'$L=4$', alpha=1.0)
ax3.plot(jlist,b,  'o', lw=1.0,  mfc=fcl[2],mec=ecl[2], ms=8,mew=0.5,  label=r'$L=8$', alpha=1.0)
ax3.plot(jlist,c,  'o', lw=1.0,  mfc=fcl[1],mec=ecl[1], ms=8,mew=0.5,  label=r'$L=12$', alpha=1.0)
ax3.xaxis.set_major_locator(MultipleLocator(0.4))
ax3.xaxis.set_minor_locator(MultipleLocator(0.2))
ax3.yaxis.set_major_locator(MultipleLocator(0.2))
ax3.yaxis.set_minor_locator(MultipleLocator(0.1))
ax3.set_ylim([-0.02,0.42])
ax3.set_xlabel(r'$J_1/J_0$ ', fontsize=fs[1])
ax3.set_ylabel(r'$I_q\ \left(A:C\ |\ B\right)$',fontsize=fs[1])
ax3.tick_params(axis='both', which='major', labelsize=fs[2])

ax3.tick_params(axis='both', which='major', labelsize=fs[2],length=5,width=1)
ax3.tick_params(axis='both', which='minor', labelsize=fs[2],length=3,width=1)
ax3.set_facecolor("none") 
ax3.legend(loc=[0.62,0.65],fontsize=fs[2],frameon=False,handletextpad=0.1)
ax3.spines['top'].set_linewidth(1)
ax3.spines['bottom'].set_linewidth(1)
ax3.spines['left'].set_linewidth(1)
ax3.spines['right'].set_linewidth(1)

L=[20,14,12,10,8]
c=[1.048,1.064,1.073,1.084,1.102]
b=[0.7005,0.6995,0.6996,0.7004,0.703]
x=np.linspace(0.01,14,1000)
y=c[1]/3*np.log(14/3.14*np.sin(3.14*x/14))+b[1]
ax4.plot(x,y,'-',lw=2,color=ecl[0],alpha=0.5,label=r'$\frac{c}{3}\log(\ \frac{L}{\pi}\ \sin( \frac{\pi L_A}{L} )\ )+b$')
Llist=np.linspace(1,13,13)
ax4.plot(Llist,CFT[0], 'D', lw=2, mfc=fcl[0],mec=ecl[0],mew=1.0, ms=7,label='data')

ax4.xaxis.set_major_locator(MultipleLocator(2))
ax4.xaxis.set_minor_locator(MultipleLocator(1))
ax4.yaxis.set_major_locator(MultipleLocator(1.0))
ax4.yaxis.set_minor_locator(MultipleLocator(0.5))
ax4.set_xlim([0,14])
ax4.set_ylim([-0.1,2.3])
ax4.set_xlabel(r'$L_A$',fontsize=fs[1])
ax4.set_ylabel(r'$S_A(L_A, L)$',fontsize=fs[1])
ax4.tick_params(axis='both', which='major', labelsize=fs[2],length=5,width=1)
ax4.tick_params(axis='both', which='minor', labelsize=fs[2],length=3,width=1)
ax4.set_facecolor("none") 
ax4.legend(fontsize=fs[2],frameon=False)
ax4.spines['top'].set_linewidth(1)
ax4.spines['bottom'].set_linewidth(1)
ax4.spines['left'].set_linewidth(1)
ax4.spines['right'].set_linewidth(1)


# ax5.plot(np.array(L[1:]),c[1:],'D',mfc=fcl[0],mec=ecl[0], ms=7,mew=1.2)
# ax5.set_xlim([7,15])
# ax5.set_ylim([-0.0,2.0])
# ax5.set_xlabel(r'$L$',fontsize=fs[1])
# ax5.set_ylabel(r'c',fontsize=16)
# ax5.tick_params(axis='both', which='major', labelsize=fs[2],width=1,length=5)
# ax5.tick_params(axis='both', which='minor', labelsize=fs[2],width=1,length=3)
# ax5.xaxis.set_major_locator(MultipleLocator(2))
# ax5.xaxis.set_minor_locator(MultipleLocator(1))
# ax5.yaxis.set_major_locator(MultipleLocator(1))
# ax5.yaxis.set_minor_locator(MultipleLocator(1))
# ax5.spines['top'].set_linewidth(1)
# ax5.spines['bottom'].set_linewidth(1)
# ax5.spines['left'].set_linewidth(1)
# ax5.spines['right'].set_linewidth(1)

# ax20.spines['top'].set_linewidth(1)
# ax20.spines['bottom'].set_linewidth(1)
# ax20.spines['left'].set_linewidth(1)
# ax20.spines['right'].set_linewidth(1)


plt.savefig('fig2-1.pdf',dpi=600)
# plt.savefig('../../Draft/fig2-1.pdf',dpi=600) 
plt.show()

# %% [markdown]
# ## fig3

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import matplotlib.ticker as ticker

import xlrd 
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from pdf2image import convert_from_path
import matplotlib.patches as patches
from mpl_toolkits.mplot3d import Axes3D  

# %matplotlib inline


# %config InlineBackend.figure_format = 'retina'

col_width = 3.375 * 2# inch
fs = np.array([10, 7, 5.5])*2 # text, label, tick

# define white-jet colormap    
upper = mpl.cm.coolwarm(np.arange(256))
lower = np.ones((int(256/4),4))
for i in range(3):
    lower[:,i] = np.linspace(1, upper[0,i], lower.shape[0])
mycmap = np.vstack(( lower, upper ))
mycmap = mpl.colors.ListedColormap(mycmap, name='mycmap', N=mycmap.shape[0])

# %%
from matplotlib.colors import ListedColormap,LinearSegmentedColormap
clist=['w','#096A94']
newcmp = LinearSegmentedColormap.from_list('chaos',clist)
clist=['w','#8A1A1C']
newcmp1 = LinearSegmentedColormap.from_list('chaos',clist)

# %%
workbook = xlrd.open_workbook('./fig34dynamic.xls')


sheet_name = ["Nring"]
cor=[]
for name in sheet_name:

    worksheet = workbook.sheet_by_name(name)
    
    offset = -1
    
    cols = []
    for i, row in enumerate(range(worksheet.ncols)):
        if i <= offset:
            continue
        c = []
        for j, row in enumerate(range(worksheet.nrows)):
            c.append(worksheet.cell_value(j, i))
        cols.append(c)
    
    for col in cols:
        u = 1
        for j in range(len(col)):
            if '' in col: 
                col.remove('') 
            if '--' in col: 
                col.remove('--') 
    cor.append(cols)
neelring=np.array(cor[0])    

sheet_name = ["Nringfq"]
cor=[]
for name in sheet_name:

    worksheet = workbook.sheet_by_name(name)
    
    offset = -1
    
    cols = []
    for i, row in enumerate(range(worksheet.ncols)):
        if i <= offset:
            continue
        c = []
        for j, row in enumerate(range(worksheet.nrows)):
            c.append(worksheet.cell_value(j, i))
        cols.append(c)
    
    for col in cols:
        u = 1
        for j in range(len(col)):
            if '' in col: 
                col.remove('') 
            if '--' in col: 
                col.remove('--') 
    cor.append(cols)
neelringfq=np.array(cor[0])    

sheet_name = ["Dring"]
cor=[]
for name in sheet_name:

    worksheet = workbook.sheet_by_name(name)
    
    offset = -1
    
    cols = []
    for i, row in enumerate(range(worksheet.ncols)):
        if i <= offset:
            continue
        c = []
        for j, row in enumerate(range(worksheet.nrows)):
            c.append(worksheet.cell_value(j, i))
        cols.append(c)
    
    for col in cols:
        u = 1
        for j in range(len(col)):
            if '' in col: 
                col.remove('') 
            if '--' in col: 
                col.remove('--') 
    cor.append(cols)
dwring=np.array(cor[0])    

sheet_name = ["Dringfq"]
cor=[]
for name in sheet_name:

    worksheet = workbook.sheet_by_name(name)
    
    offset = -1
    
    cols = []
    for i, row in enumerate(range(worksheet.ncols)):
        if i <= offset:
            continue
        c = []
        for j, row in enumerate(range(worksheet.nrows)):
            c.append(worksheet.cell_value(j, i))
        cols.append(c)
    
    for col in cols:
        u = 1
        for j in range(len(col)):
            if '' in col: 
                col.remove('') 
            if '--' in col: 
                col.remove('--') 
    cor.append(cols)
dwringfq=np.array(cor[0])    

sheet_name = ["Nxx"]
cor=[]
for name in sheet_name:

    worksheet = workbook.sheet_by_name(name)
    
    offset = -1
    
    cols = []
    for i, row in enumerate(range(worksheet.ncols)):
        if i <= offset:
            continue
        c = []
        for j, row in enumerate(range(worksheet.nrows)):
            c.append(worksheet.cell_value(j, i))
        cols.append(c)
    
    for col in cols:
        u = 1
        for j in range(len(col)):
            if '' in col: 
                col.remove('') 
            if '--' in col: 
                col.remove('--') 
    cor.append(cols)
neelxx=np.array(cor[0])    
    
sheet_name = ["Dxx"]
cor=[]
for name in sheet_name:

    worksheet = workbook.sheet_by_name(name)
    
    offset = -1
    
    cols = []
    for i, row in enumerate(range(worksheet.ncols)):
        if i <= offset:
            continue
        c = []
        for j, row in enumerate(range(worksheet.nrows)):
            c.append(worksheet.cell_value(j, i))
        cols.append(c)
    
    for col in cols:
        u = 1
        for j in range(len(col)):
            if '' in col: 
                col.remove('') 
            if '--' in col: 
                col.remove('--') 
    cor.append(cols)
dwxx=np.array(cor[0])

# %%
aaa=np.zeros(101)
bbb=np.zeros(101)
ccc=np.zeros(201)
for i in range(9):
    aaa+=neelring[:,2*i]*(-1)**(i+1)
    bbb+=neelxx[:,2*i]*(-1)**(i+1)
    ccc+=neelringfq[:,2*i]*(-1)**(i+1)
ineel4=aaa[:101]
ineel2=bbb[:101]
ineel4f=ccc[:201]
# iex=-(np.sum(ex[:,::2],1)-np.array(ex[:,8])*2)[:101]

idw4=-(np.sum(dwring[:,::2],1))[:101]
idw2=-(np.sum(dwxx[:,::2],1))[:101]
idw4f=-(np.sum(dwringfq[:,::2],1))[:201]
ttol=10
step=101
tlist=np.linspace(0,ttol,step)[:101]######eff
ttol=10
step=201
tlist0=np.linspace(0,ttol,step)[:201]######floquet

# %%
aaa=np.zeros(101)
bbb=np.zeros(101)
ccc=np.zeros(201)
for i in range(9):

    aaa+=neelring[:,2*i]
    bbb+=neelxx[:,2*i]
    ccc+=neelringfq[:,2*i]
zneel4=aaa[:101]
zneel2=bbb[:101]
zneel4f=ccc[:201]

aaa=np.zeros(101)
bbb=np.zeros(101)
ccc=np.zeros(201)
for i in range(9):
    aaa+=dwring[:,2*i]
    bbb+=dwxx[:,2*i]
    ccc+=dwringfq[:,2*i]
zdw4=aaa[:101]
zdw2=bbb[:101]
zdw4f=ccc[:201]

# %%
fcl=["#B8D5E2",'#E0B8B8',"#D9D9D9","#BCE5A8"]
ecl=['#096A94','#8A1A1C',"#636363","#31711B"]

# %%
plt.style.use(['science'])

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "sans-serif",# specify font family here
    "font.sans-serif": "Arial",
    "mathtext.fontset":"stixsans",
    "font.size":11,
    "savefig.bbox": "standard",
    'xtick.top': False,
    'ytick.right': False,
    'xtick.direction':'in',
    'ytick.direction':'out',
    }) 




fig = plt.figure(figsize=[col_width*1,col_width*1],
                 facecolor='w')
fig.text(0.030, 0.96, r'a', size=fs[0])
fig.text(0.030, 0.79, r'b', size=fs[0])
fig.text(0.030, 0.43, r'c', size=fs[0])

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "sans-serif",# specify font family here
    "font.sans-serif": "Helvetica Neue",
    "mathtext.fontset":"stixsans",
    "font.size":11,
    "savefig.bbox": "standard",
    'xtick.top': False,
    'ytick.right': False,
    'xtick.direction':'in',
    'ytick.direction':'out',
    }) 
color=['#891A1C','#096A93']

ax0 = fig.add_axes([0.2,0.46,0.63,0.35])
ax00= fig.add_axes([0.2,0.10,0.63,0.35])
ax1 = fig.add_axes([0.2, 0.915,0.18,0.04])
ax2 = fig.add_axes([0.425,0.915,0.18,0.04])
ax3 = fig.add_axes([0.65, 0.915,0.18,0.04])

ax4 = fig.add_axes([0.2, 0.86,0.18,0.04])
ax5 = fig.add_axes([0.425,0.86,0.18,0.04])
ax6 = fig.add_axes([0.65, 0.86,0.18,0.04])

# ax2 = fig.add_axes([0.40,0.300,0.2,0.2])



for cx,cs,cax in zip([0.19,1.69,3.19],
                 [r'$t=0$',r'$t=2J_R$',r'$t=4J_R$'],
                    [ax1,ax2,ax3]):
#     ax0.text(cx,1.07, cs,
#              fontsize=fs[2],
#              ha="center", 
#              va="center",
#              bbox = dict(boxstyle=f"circle, pad={0.10}",fc="w",lw=0.75,alpha=1),zorder=20)
    cax.text(0,2.5, cs,
             fontsize=fs[2],
             ha="left", 
             va="center")
#              bbox = dict(boxstyle=f"circle, pad={0.10}",fc="w",lw=0.75,alpha=1),zorder=20)


C=(dwring[0])
C.reshape(9,2)
xm, ym = np.meshgrid(np.linspace(-0.5,9.5,10),np.linspace(-0.5,1.5,3))
hd1=ax1.pcolormesh(xm,ym,-(C.reshape(9,2)).T,cmap=newcmp,shading='flat',edgecolor='#333333',alpha=0.7,vmin=-0.5,vmax=0.5)
ax1.set_xticks([])
ax1.set_yticks([])
ax1.text(-7,0.5,r'$\hat{S}_{DW}^z$',color=ecl[0],ha='left',va='center',fontsize=fs[1])

C=(dwring[20])
C.reshape(9,2)
hd1=ax2.pcolormesh(xm,ym,-(C.reshape(9,2)).T,cmap=newcmp,shading='flat',edgecolor='#333333',alpha=0.7,vmin=-0.5,vmax=0.5)
ax2.set_xticks([])
ax2.set_yticks([])

C=(dwring[40])
C.reshape(9,2)
hd1=ax3.pcolormesh(xm,ym,-(C.reshape(9,2)).T,cmap=newcmp,shading='flat',edgecolor='#333333',alpha=0.7,vmin=-0.5,vmax=0.5)
ax3.set_xticks([])
ax3.set_yticks([])


C=(neelring[0])
C.reshape(9,2)
hd1=ax4.pcolormesh(xm,ym,-(C.reshape(9,2)).T,cmap=newcmp,shading='flat',edgecolor='#333333',alpha=0.7,vmin=-0.5,vmax=0.5)
ax4.set_xticks([])
ax4.set_yticks([])
ax4.text(-7,0.5,r'$\hat{S}_{N\'{e}el}^z$',color=ecl[1],ha='left',va='center',fontsize=fs[1])
C=(neelring[20])
C.reshape(9,2)
hd1=ax5.pcolormesh(xm,ym,-(C.reshape(9,2)).T,cmap=newcmp,shading='flat',edgecolor='#333333',alpha=0.7,vmin=-0.5,vmax=0.5)
ax5.set_xticks([])
ax5.set_yticks([])

C=(neelring[40])
C.reshape(9,2)
hd1=ax6.pcolormesh(xm,ym,-(C.reshape(9,2)).T,cmap=newcmp,shading='flat',edgecolor='#333333',alpha=0.7,vmin=-0.5,vmax=0.5)
ax6.set_xticks([])
ax6.set_yticks([])
ax6.text(12,1.8,r'$\mathrm{\langle \hat{S}^z \rangle}$',fontsize=fs[1],va='center')

clevs = [-0.5,0.5]
cax1 = inset_axes(ax6,width='10%',height='240%',
                 bbox_to_anchor=[0.22,1.65,1,1],
                 bbox_transform=ax6.transAxes)
cbar=plt.colorbar(hd1, cax=cax1,ticks=clevs)

cax1.tick_params(axis='both', which='major', labelsize=fs[2])


ax0.vlines([0,2,4],-1.1,2.1,linestyle=(0,(4,2)),lw=2,color='gray',alpha=0.5,zorder=2)
ax00.vlines([0,2,4],-1.1,2.1,linestyle=(0,(4,2)),lw=2,color='gray',alpha=0.5,zorder=2)


ax0.plot(tlist,idw4/4.5,  color=ecl[0],alpha=0.5,lw=1.5)
ax0.plot(tlist,ineel4/4.5,color=ecl[1],alpha=0.5,lw=1.5)
# ax0.plot(tlist0,idw4f/4.5,  color=ecl[0],alpha=0.5,lw=1.5)
# ax0.plot(tlist0,ineel4f/4.5,color=ecl[1],alpha=0.5,lw=1.5)
ax0.plot(tlist,idw2/4.5,  color=ecl[0],alpha=0.5,lw=1.5)
ax0.plot(tlist,ineel2/4.5,color=ecl[1],alpha=0.5,lw=1.5)



ax0.plot(tlist[::5],  idw4[::5]/4.5,'^',mec=ecl[0],mew=1.2,  ms=8,mfc=fcl[0],label='DW Fracton model')
ax0.plot(tlist[::6],ineel4[::6]/4.5,'^',mec=ecl[1],mew=1.2,  ms=8,mfc=fcl[1],label='Neel Fracton modol')
ax0.plot(tlist[::5],  idw2[::5]/4.5,'s',mec=ecl[0],mew=1.2,  ms=8,mfc=fcl[0],label='DW XX model')
ax0.plot(tlist[::5],ineel2[::5]/4.5,'s',mec=ecl[1],mew=1.2,  ms=8,mfc=fcl[1],label='Neel XX model')

ax0.set_xlim([-0.15,5.1])
ax0.set_ylim([-0.6,1.15])
ax0.yaxis.set_major_locator(MultipleLocator(0.5))
ax0.yaxis.set_minor_locator(MultipleLocator(0.1))

ax0.tick_params(axis='both', which='major', labelsize=fs[2],length=5,width=1)
ax0.tick_params(axis='both', which='minor', labelsize=fs[2],length=3,width=1)
ax0.set_ylabel(r'Imbalance',fontsize=fs[1])
ax0.set_xticks([])
ax0.spines['top'].set_linewidth(1)
ax0.spines['bottom'].set_linewidth(1)
ax0.spines['left'].set_linewidth(1)
ax0.spines['right'].set_linewidth(1)
ax0.legend(loc=[0.2,0.6],fontsize=fs[2],handletextpad=0.1,ncol=2,columnspacing=0.4)




ax00.plot(tlist,-zdw4/4.5,'-',  color=ecl[0],alpha=0.5,lw=1.5)
ax00.plot(tlist,-zneel4/0.5,'-',  color=ecl[1],alpha=0.5,lw=1.5)
ax00.plot(tlist,-zdw2/4.5,'-',color=ecl[0],alpha=0.5,lw=1.5)
ax00.plot(tlist,-zneel2/0.5,    color=ecl[1],alpha=0.5,lw=1.5)


ax00.plot(tlist[::5],  -zdw4[::5]/4.5,'^',mfc=fcl[0],mew=1.2,  ms=8,mec=ecl[0],label='DW Fracton model')
ax00.plot(tlist[::6],-zneel4[::6]/0.5,'^',mfc=fcl[1],mew=1.2,  ms=8,mec=ecl[1],label='Neel Fracton model')
ax00.plot(tlist[::5],  -zdw2[::5]/4.5,'s',mfc=fcl[0],mew=1.2,  ms=8,mec=ecl[0],label='DW XX model')
ax00.plot(tlist[::5],-zneel2[::5]/0.5,'s',mfc=fcl[1],mew=1.2,  ms=8,mec=ecl[1],label='Neel XX model')



ax00.set_xlim([-0.15,5.1])
ax00.set_ylim([-1.05,1.15])
ax00.yaxis.set_major_locator(MultipleLocator(0.5))
ax00.yaxis.set_minor_locator(MultipleLocator(0.1))

ax00.tick_params(axis='both', which='major', labelsize=fs[2],length=5,width=1)
ax00.tick_params(axis='both', which='minor', labelsize=fs[2],length=3,width=1)
ax00.set_ylabel(r'Magnetization $\mathrm{\langle \hat{M}^z \rangle}$',fontsize=fs[1])
ax00.set_xlabel(r'Time $ / J_R$', fontsize=fs[1])
ax00.spines['top'].set_linewidth(1)
ax00.spines['bottom'].set_linewidth(1)
ax00.spines['left'].set_linewidth(1)
ax00.spines['right'].set_linewidth(1)


plt.savefig('fig3-1.pdf',dpi=600)
# plt.savefig('../../Draft/fig4-1.pdf',dpi=600) 
plt.show()

# %% [markdown]
# ## fig4

# %%
workbook = xlrd.open_workbook('./fig34dynamic.xls')

sheet_name = ["exring"]
cor=[]
for name in sheet_name:

    worksheet = workbook.sheet_by_name(name)
    
    offset = -1
    
    cols = []
    for i, row in enumerate(range(worksheet.ncols)):
        if i <= offset:
            continue
        c = []
        for j, row in enumerate(range(worksheet.nrows)):
            c.append(worksheet.cell_value(j, i))
        cols.append(c)
    
    for col in cols:
        u = 1
        for j in range(len(col)):
            if '' in col: 
                col.remove('') 
            if '--' in col: 
                col.remove('--') 
    cor.append(cols)
exring=np.array(cor[0])  
sheet_name = ["exringt2"]
cor=[]
for name in sheet_name:

    worksheet = workbook.sheet_by_name(name)
    
    offset = -1
    
    cols = []
    for i, row in enumerate(range(worksheet.ncols)):
        if i <= offset:
            continue
        c = []
        for j, row in enumerate(range(worksheet.nrows)):
            c.append(worksheet.cell_value(j, i))
        cols.append(c)
    
    for col in cols:
        u = 1
        for j in range(len(col)):
            if '' in col: 
                col.remove('') 
            if '--' in col: 
                col.remove('--') 
    cor.append(cols)
exringt2=np.array(cor[0])
sheet_name = ["exringt10"]
cor=[]
for name in sheet_name:

    worksheet = workbook.sheet_by_name(name)
    
    offset = -1
    
    cols = []
    for i, row in enumerate(range(worksheet.ncols)):
        if i <= offset:
            continue
        c = []
        for j, row in enumerate(range(worksheet.nrows)):
            c.append(worksheet.cell_value(j, i))
        cols.append(c)
    
    for col in cols:
        u = 1
        for j in range(len(col)):
            if '' in col: 
                col.remove('') 
            if '--' in col: 
                col.remove('--') 
    cor.append(cols)
exringt10=np.array(cor[0])

# %%
sheet_name = ["exringfq"]
cor=[]
for name in sheet_name:

    worksheet = workbook.sheet_by_name(name)
    
    offset = -1
    
    cols = []
    for i, row in enumerate(range(worksheet.ncols)):
        if i <= offset:
            continue
        c = []
        for j, row in enumerate(range(worksheet.nrows)):
            c.append(worksheet.cell_value(j, i))
        cols.append(c)
    
    for col in cols:
        u = 1
        for j in range(len(col)):
            if '' in col: 
                col.remove('') 
            if '--' in col: 
                col.remove('--') 
    cor.append(cols)
exringfq=np.array(cor[0])  
sheet_name = ["exringt2fq"]
cor=[]
for name in sheet_name:

    worksheet = workbook.sheet_by_name(name)
    
    offset = -1
    
    cols = []
    for i, row in enumerate(range(worksheet.ncols)):
        if i <= offset:
            continue
        c = []
        for j, row in enumerate(range(worksheet.nrows)):
            c.append(worksheet.cell_value(j, i))
        cols.append(c)
    
    for col in cols:
        u = 1
        for j in range(len(col)):
            if '' in col: 
                col.remove('') 
            if '--' in col: 
                col.remove('--') 
    cor.append(cols)
exringt2fq=np.array(cor[0])
sheet_name = ["exringt10fq"]
cor=[]
for name in sheet_name:

    worksheet = workbook.sheet_by_name(name)
    
    offset = -1
    
    cols = []
    for i, row in enumerate(range(worksheet.ncols)):
        if i <= offset:
            continue
        c = []
        for j, row in enumerate(range(worksheet.nrows)):
            c.append(worksheet.cell_value(j, i))
        cols.append(c)
    
    for col in cols:
        u = 1
        for j in range(len(col)):
            if '' in col: 
                col.remove('') 
            if '--' in col: 
                col.remove('--') 
    cor.append(cols)
exringt10fq=np.array(cor[0])

# %%
sheet_name = ["exxx"]
cor=[]
for name in sheet_name:

    worksheet = workbook.sheet_by_name(name)
    
    offset = -1
    
    cols = []
    for i, row in enumerate(range(worksheet.ncols)):
        if i <= offset:
            continue
        c = []
        for j, row in enumerate(range(worksheet.nrows)):
            c.append(worksheet.cell_value(j, i))
        cols.append(c)
    
    for col in cols:
        u = 1
        for j in range(len(col)):
            if '' in col: 
                col.remove('') 
            if '--' in col: 
                col.remove('--') 
    cor.append(cols)
exxx=np.array(cor[0])  
sheet_name = ["exxxt2"]
cor=[]
for name in sheet_name:

    worksheet = workbook.sheet_by_name(name)
    
    offset = -1
    
    cols = []
    for i, row in enumerate(range(worksheet.ncols)):
        if i <= offset:
            continue
        c = []
        for j, row in enumerate(range(worksheet.nrows)):
            c.append(worksheet.cell_value(j, i))
        cols.append(c)
    
    for col in cols:
        u = 1
        for j in range(len(col)):
            if '' in col: 
                col.remove('') 
            if '--' in col: 
                col.remove('--') 
    cor.append(cols)
exxxt2=np.array(cor[0])
sheet_name = ["exxxt10"]
cor=[]
for name in sheet_name:

    worksheet = workbook.sheet_by_name(name)
    
    offset = -1
    
    cols = []
    for i, row in enumerate(range(worksheet.ncols)):
        if i <= offset:
            continue
        c = []
        for j, row in enumerate(range(worksheet.nrows)):
            c.append(worksheet.cell_value(j, i))
        cols.append(c)
    
    for col in cols:
        u = 1
        for j in range(len(col)):
            if '' in col: 
                col.remove('') 
            if '--' in col: 
                col.remove('--') 
    cor.append(cols)
exxxt10=np.array(cor[0])

# %%
iexr   =(np.sum(exring[:,::2]   ,1)-np.array(exring[:,8])*2)[:101]
iexrt2 =(np.sum(exringt2[:,::2] ,1)-np.array(exringt2[:,8])*2)[:101]
iexrt10=(np.sum(exringt10[:,::2],1)-np.array(exringt10[:,8])*2)[:101]

iexrf   =(np.sum(exringfq[:,::2]   ,1)-np.array(exringfq[:,8])*2)[:201]
iexrt2f =(np.sum(exringt2fq[:,::2] ,1)-np.array(exringt2fq[:,8])*2)[:201]
iexrt10f=(np.sum(exringt10fq[:,::2],1)-np.array(exringt10fq[:,8])*2)[:201]

iexx   =(np.sum(exxx[:,::2]   ,1)-2*np.array(exxx[:,8]))[:101]
iexxt2 =(np.sum(exxxt2[:,::2] ,1)-2*np.array(exxxt2[:,8]))[:101]
iexxt10=(np.sum(exxxt10[:,::2],1)-2*np.array(exxxt10[:,8]))[:101]

# %%
plt.style.use(['science'])

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "sans-serif",# specify font family here
    "font.sans-serif": "Arial",
    "mathtext.fontset":"stixsans",
    "font.size":11,
    "savefig.bbox": "standard",
    'xtick.top': False,
    'ytick.right': False,
    'xtick.direction':'in',
    'ytick.direction':'out',
    }) 


fig = plt.figure(figsize=[col_width*1,col_width*1.0],
                 facecolor='w')
fig.text(0.020, 0.96, r'a', size=fs[0])
fig.text(0.020, 0.64, r'b', size=fs[0])
fig.text(0.020, 0.29, r'c', size=fs[0])

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "sans-serif",# specify font family here
    "font.sans-serif": "Helvetica Neue",
    "mathtext.fontset":"stixsans",
    "font.size":11,
    "savefig.bbox": "standard",
    'xtick.top': False,
    'ytick.right': False,
    'xtick.direction':'in',
    'ytick.direction':'out',
    }) 


color=['#891A1C','#096A93']

ax0 = fig.add_axes  ([0.15,0.1,0.2,0.2])
ax00 = fig.add_axes ([0.42,0.1,0.2,0.2])
ax000 = fig.add_axes([0.69,0.1,0.2,0.2])
ax1 = fig.add_axes([0.15,  0.70,0.2, 0.25])
ax2 = fig.add_axes([0.42,  0.70,0.2, 0.25])
ax3 = fig.add_axes([0.69,  0.70,0.2, 0.25])
ax4 = fig.add_axes([0.15, 0.40,0.2,0.25])
ax5 = fig.add_axes([0.42, 0.40,0.2,0.25])
ax6 = fig.add_axes([0.69, 0.40,0.2,0.25])






xm, ym = np.meshgrid(np.linspace(-0.5,8.5,10),np.linspace(-0.05,2.05,22))
hd1=ax1.pcolormesh(xm,ym,exring.T[::2,::5].T,cmap=newcmp1,shading='flat')
ax1.invert_yaxis()
ax1.yaxis.set_major_locator(MultipleLocator(0.5))
ax1.yaxis.set_minor_locator(MultipleLocator(0.1))
ax1.xaxis.set_major_locator(MultipleLocator(2))
ax1.xaxis.set_minor_locator(MultipleLocator(1))
ax1.tick_params(axis='both', which='major', labelsize=fs[2],length=5,width=1)
ax1.tick_params(axis='both', which='minor', labelsize=fs[2],length=3,width=1)
ax1.set_ylabel(r'Time $ / J_R$', fontsize=fs[1])
ax1.text(0,-0.15,r'$\Delta_j=0$',fontsize=fs[2])


hd1=ax2.pcolormesh(xm,ym,exringt2.T[::2,::5].T,cmap=newcmp1,shading='flat')
ax2.invert_yaxis()
ax2.yaxis.set_major_locator(MultipleLocator(0.5))
ax2.yaxis.set_minor_locator(MultipleLocator(0.1))
ax2.xaxis.set_major_locator(MultipleLocator(2))
ax2.xaxis.set_minor_locator(MultipleLocator(1))
ax2.tick_params(axis='both', which='major', labelsize=fs[2],length=5,width=1)
ax2.tick_params(axis='both', which='minor', labelsize=fs[2],length=3,width=1)
# ax2.set_xlabel(r'Site',fontsize=fs[1])
# ax2.set_ylabel(r'$t\ /\ J_R$', fontsize=fs[1])
ax2.text(0,-0.15,r'$\Delta_j=2J_R$',fontsize=fs[2])

hd1=ax3.pcolormesh(xm,ym,exringt10.T[::2,::5].T,cmap=newcmp1,shading='flat')
ax3.invert_yaxis()
ax3.yaxis.set_major_locator(MultipleLocator(0.5))
ax3.yaxis.set_minor_locator(MultipleLocator(0.1))
ax3.xaxis.set_major_locator(MultipleLocator(2))
ax3.xaxis.set_minor_locator(MultipleLocator(1))
ax3.tick_params(axis='both', which='major', labelsize=fs[2],length=5,width=1)
ax3.tick_params(axis='both', which='minor', labelsize=fs[2],length=3,width=1)
# ax3.set_xlabel(r'Site',fontsize=fs[1])
# ax3.set_ylabel(r'$t\ /\ J_R$', fontsize=fs[1])
ax3.text(0,-0.15,r'$\Delta_j=10J_R$',fontsize=fs[2])
ax3.text(10.8,1.0,r'$\mathrm{\langle \hat{S}^z \rangle}$',fontsize=fs[1],va='center')

clevs = [-0.5,0.5]
cax1 = inset_axes(ax3,width='10%',height='100%',
                 bbox_to_anchor=[0.2,0.05,1,1],
                 bbox_transform=ax3.transAxes)
cbar=plt.colorbar(hd1, cax=cax1,ticks=clevs)

cax1.tick_params(axis='both', which='major', labelsize=fs[2])


hd1=ax4.pcolormesh(xm,ym,exxx.T[::2,::5].T,cmap=newcmp,shading='flat')
ax4.invert_yaxis()
ax4.yaxis.set_major_locator(MultipleLocator(0.5))
ax4.yaxis.set_minor_locator(MultipleLocator(0.1))
ax4.xaxis.set_major_locator(MultipleLocator(2))
ax4.xaxis.set_minor_locator(MultipleLocator(1))
ax4.tick_params(axis='both', which='major', labelsize=fs[2],length=5,width=1)
ax4.tick_params(axis='both', which='minor', labelsize=fs[2],length=3,width=1)
# ax4.set_xlabel(r'Site',fontsize=fs[1])
ax4.set_ylabel(r'Time $ / J_R$', fontsize=fs[1])

hd1=ax5.pcolormesh(xm,ym,exxxt2.T[::2,::5].T,cmap=newcmp,shading='flat')
ax5.invert_yaxis()
ax5.yaxis.set_major_locator(MultipleLocator(0.5))
ax5.yaxis.set_minor_locator(MultipleLocator(0.1))
ax5.xaxis.set_major_locator(MultipleLocator(2))
ax5.xaxis.set_minor_locator(MultipleLocator(1))
ax5.tick_params(axis='both', which='major', labelsize=fs[2],length=5,width=1)
ax5.tick_params(axis='both', which='minor', labelsize=fs[2],length=3,width=1)
ax5.set_xlabel(r'Site',fontsize=fs[1])
# ax5.set_ylabel(r'$t\ /\ J_R$', fontsize=fs[1])

hd1=ax6.pcolormesh(xm,ym,exxxt10.T[::2,::5].T,cmap=newcmp,shading='flat')
ax6.invert_yaxis()
ax6.yaxis.set_major_locator(MultipleLocator(0.5))
ax6.yaxis.set_minor_locator(MultipleLocator(0.1))
ax6.xaxis.set_major_locator(MultipleLocator(2))
ax6.xaxis.set_minor_locator(MultipleLocator(1))
ax6.tick_params(axis='both', which='major', labelsize=fs[2],length=5,width=1)
ax6.tick_params(axis='both', which='minor', labelsize=fs[2],length=3,width=1)
# ax6.set_xlabel(r'Site',fontsize=fs[1])
# ax6.set_ylabel(r'$t\ /\ J_R$', fontsize=fs[1])
ax6.text(10.8,1.0,r'$\mathrm{\langle \hat{S}^z \rangle}$',fontsize=fs[1],va='center')

clevs = [-0.5,0.5]
cax1 = inset_axes(ax6,width='10%',height='100%',
                 bbox_to_anchor=[0.2,0.05,1,1],
                 bbox_transform=ax6.transAxes)
cbar=plt.colorbar(hd1, cax=cax1,ticks=clevs)

cax1.tick_params(axis='both', which='major', labelsize=fs[2])



tlist=np.linspace(0,2,101)
tlist0=np.linspace(0,10,201)
ax0.plot(tlist,-iexx/4.5,color=ecl[0],alpha=0.5,lw=2.5,label='XX model')
ax0.plot(tlist,-iexr/4.5,color=ecl[1],alpha=0.5,lw=2.5,label='Fracton model')
ax0.plot(tlist[::10],-iexx[::10]/4.5,'D',mec=ecl[0],mfc=fcl[0],alpha=1.0,mew=1.2,label='XX model')
ax0.plot(tlist[::10],-iexr[::10]/4.5,'o',mec=ecl[1],mfc=fcl[1],alpha=1.0,mew=1.2,label='Fracton model')

ax0.set_xlim([-0.15,2.1])
ax0.set_ylim([-0.1,1.15])
ax0.xaxis.set_major_locator(MultipleLocator(1.0))
ax0.xaxis.set_minor_locator(MultipleLocator(0.5))
ax0.yaxis.set_major_locator(MultipleLocator(0.5))
ax0.yaxis.set_minor_locator(MultipleLocator(0.1))
ax0.tick_params(axis='both', which='major', labelsize=fs[2],length=5,width=1)
ax0.tick_params(axis='both', which='minor', labelsize=fs[2],length=3,width=1)
ax0.set_xlabel(r'Time $ / J_R$', fontsize=fs[1])
ax0.set_ylabel(r'Imbalance',fontsize=fs[1])

ax00.plot(tlist,-iexxt2/4.5,color=ecl[0],alpha=0.5,lw=2.5,label='XX model')
ax00.plot(tlist,-iexrt2/4.5,color=ecl[1],alpha=0.5,lw=2.5,label='Fracton model')
ax00.plot(tlist[::10],-iexxt2[::10]/4.5,'D',mec=ecl[0],mfc=fcl[0],alpha=1.0,mew=1.2,label='XX model')
ax00.plot(tlist[::10],-iexrt2[::10]/4.5,'o',mec=ecl[1],mfc=fcl[1],alpha=1.0,mew=1.2,label='Fracton model')

ax00.set_xlim([-0.15,2.1])
ax00.set_ylim([-0.1,1.15])
ax00.xaxis.set_major_locator(MultipleLocator(1.0))
ax00.xaxis.set_minor_locator(MultipleLocator(0.5))
ax00.yaxis.set_major_locator(MultipleLocator(0.5))
ax00.yaxis.set_minor_locator(MultipleLocator(0.1))
ax00.tick_params(axis='both', which='major', labelsize=fs[2],length=5,width=1)
ax00.tick_params(axis='both', which='minor', labelsize=fs[2],length=3,width=1)
ax00.set_xlabel(r'Time $ / J_R$', fontsize=fs[1])


ax000.plot(tlist,-iexxt10/4.5,color=ecl[0],alpha=0.5,lw=2.5)
ax000.plot(tlist,-iexrt10/4.5,color=ecl[1],alpha=0.5,lw=2.5)
ax000.plot(tlist[::10],-iexxt10[::10]/4.5,'D',mec=ecl[0],mfc=fcl[0],alpha=1.0,mew=1.2,label='XX model')
ax000.plot(tlist[::10],-iexrt10[::10]/4.5,'o',mec=ecl[1],mfc=fcl[1],alpha=1.0,mew=1.2,label='Fracton model')
ax000.set_xlim([-0.15,2.1])
ax000.set_ylim([-0.1,1.15])
ax000.xaxis.set_major_locator(MultipleLocator(1.0))
ax000.xaxis.set_minor_locator(MultipleLocator(0.5))
ax000.yaxis.set_major_locator(MultipleLocator(0.5))
ax000.yaxis.set_minor_locator(MultipleLocator(0.25))
ax000.tick_params(axis='both', which='major', labelsize=fs[2],length=5,width=1)
ax000.tick_params(axis='both', which='minor', labelsize=fs[2],length=3,width=1)
ax000.set_xlabel(r'Time $ / J_R$', fontsize=fs[1])
#ax000.set_ylabel(r'Imbalance',fontsize=fs[1])
ax000.legend(loc=[-0.05,0.00],fontsize=fs[2],handletextpad=-0.3)




plt.savefig('fig4.pdf',dpi=600)
# plt.savefig('../../Draft/fig5.pdf',dpi=600) 
plt.show()

# %% [markdown]
# ## fig5

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import matplotlib.ticker as ticker

import xlrd 
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from pdf2image import convert_from_path

from mpl_toolkits.mplot3d import Axes3D  

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

col_width = 3.375 * 2# inch
fs = np.array([10, 7, 5.5])*2 # text, label, tick

from matplotlib.colors import ListedColormap,LinearSegmentedColormap
clist=['w','#A8B7D5','#CA3B23']
clist=['w','#3C658D','#973857']
newcmp = LinearSegmentedColormap.from_list('chaos',clist)
fcl=["#B8D5E2",'#E0B8B8',"#D9D9D9","#BCE5A8","#FFF299"]
ecl=['#096A94','#8A1A1C',"#636363","#31711B","#E68000"]

# %%
workbook = xlrd.open_workbook('./fig5.xls')
sheet_name = ["opt_evo"]
opt=[]
for name in sheet_name:

    worksheet = workbook.sheet_by_name(name)
    
    offset = -1
    
    cols = []
    for i, row in enumerate(range(worksheet.ncols)):
        if i <= offset:
            continue
        c = []
        for j, row in enumerate(range(worksheet.nrows)):
            c.append(worksheet.cell_value(j, i))
        cols.append(c)
    
    for col in cols:
        u = 1
        for j in range(len(col)):
            if '' in col: 
                col.remove('') 
            if '--' in col: 
                col.remove('--') 
    cls=cols
    opt.append(cols)

sheet_name = ["corr"]
cor=[]
for name in sheet_name:

    worksheet = workbook.sheet_by_name(name)
    
    offset = -1
    
    cols = []
    for i, row in enumerate(range(worksheet.ncols)):
        if i <= offset:
            continue
        c = []
        for j, row in enumerate(range(worksheet.nrows)):
            c.append(worksheet.cell_value(j, i))
        cols.append(c)
    
    for col in cols:
        u = 1
        for j in range(len(col)):
            if '' in col: 
                col.remove('') 
            if '--' in col: 
                col.remove('--') 
    cor.append(cols)
cor=np.array(cor)    

sheet_name = ["lcorr"]
lcor=[]
for name in sheet_name:

    worksheet = workbook.sheet_by_name(name)
    
    offset = -1
    
    cols = []
    for i, row in enumerate(range(worksheet.ncols)):
        if i <= offset:
            continue
        c = []
        for j, row in enumerate(range(worksheet.nrows)):
            c.append(worksheet.cell_value(j, i))
        cols.append(c)
    
    for col in cols:
        u = 1
        for j in range(len(col)):
            if '' in col: 
                col.remove('') 
            if '--' in col: 
                col.remove('--') 
    lcor.append(cols)
lcor=np.array(lcor)    

sheet_name = ["lin_evo"]
lin=[]
for name in sheet_name:

    worksheet = workbook.sheet_by_name(name)
    
    offset = -1
    
    cols = []
    for i, row in enumerate(range(worksheet.ncols)):
        if i <= offset:
            continue
        c = []
        for j, row in enumerate(range(worksheet.nrows)):
            c.append(worksheet.cell_value(j, i))
        cols.append(c)
    
    for col in cols:
        u = 1
        for j in range(len(col)):
            if '' in col: 
                col.remove('') 
            if '--' in col: 
                col.remove('--') 
    lin.append(cols)
# params= [8.88026234e-01, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#          1.00000000e+00, 6.61164514e-01, 1.00000000e+00, 1.00000000e+00,
#          1.00000000e+00, 1.00000000e-05, 1.00000000e+00, 1.00000000e+00,
#          1.00000000e+00, 1.00000000e-05, 1.00000000e+00, 1.00000000e+00,
#          1.00000000e+00, 1.00000000e-05, 1.00000000e+00, 1.00000000e-05,
#          1.00000000e+00, 1.00000000e-05, 1.00000000e+00, 4.66891949e-03,
#          1.00000000e+00, 1.00000000e-05, 1.00000000e+00, 1.00000000e+00,
#          1.00000000e+00, 1.00000000e+00, 2.66457921e-01, 1.00000000e+00,
#          1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#          1.00000000e+00, 1.00000000e-05, 1.00000000e+00, 1.00000000e+00,
#          1.00000000e-05, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#          1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#          1.00000000e+00, 1.00000000e-05, 1.00000000e-05, 1.00000000e-05,
#          1.00000000e+00, 1.00000000e-05, 1.00000000e+00, 1.00000000e-05,
#          1.00000000e+00, 1.00000000e-05, 1.00000000e-05, 1.00000000e-05]
opt=np.mat(opt[0])
lin=np.mat(lin[0])
sheet_name = ["con"]
evo=[]
for name in sheet_name:
    worksheet = workbook.sheet_by_name(name)
    offset = -1
    cols = []
    for i, row in enumerate(range(worksheet.ncols)):
        if i <= offset:
            continue
        c = []
        for j, row in enumerate(range(worksheet.nrows)):
            c.append(worksheet.cell_value(j, i))
        cols.append(c)
    
    for col in cols:
        u = 1
        for j in range(len(col)):
            if '' in col: 
                col.remove('') 
            if '--' in col: 
                col.remove('--') 
    evo.append(cols)
x=np.linspace(1,1000,1000)
min1=np.zeros(1000)
for i in range(1000):
    min1[i]=np.max(evo[0][0][1:(i+2)])

# %%
plt.style.use(['science'])

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "sans-serif",   # specify font family here
    "font.sans-serif": "Arial",
    "mathtext.fontset":"stixsans",
    "font.size":11,
    "savefig.bbox": "standard",
    'xtick.top': False,
    'ytick.right': False,
    'xtick.direction':'in',
    'ytick.direction':'out',
    'axes.linewidth':1,
    }) 


fig = plt.figure(figsize=[col_width*1,col_width*0.8],
                 facecolor='w')
fig.text(0.020, 0.96, r'a', size=fs[0])
fig.text(0.53,  0.96, r'c', size=fs[0])
fig.text(0.020, 0.47, r'b', size=fs[0])

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "sans-serif",# specify font family here
    "font.sans-serif": "Helvetica Neue",
    "mathtext.fontset":"stixsans",
    "font.size":11,
    "savefig.bbox": "standard",
    'xtick.top': False,
    'ytick.right': False,
    'xtick.direction':'in',
    'ytick.direction':'out',
    }) 

color=['#891A1C','#096A93']

ax0 = fig.add_axes([0.120,0.580,0.37,0.39])
#ax2 = fig.add_axes([0.63,0.700,0.37,0.265])
ax1 = fig.add_axes([0.120,0.100,0.37,0.39])
ax3 = fig.add_axes([0.610,0.100,0.32,0.17])
ax4 = fig.add_axes([0.610,0.275,0.32,0.17])
ax5 = fig.add_axes([0.610,0.450,0.32,0.17])
ax6 = fig.add_axes([0.610,0.625,0.32,0.17])
ax7 = fig.add_axes([0.610,0.800,0.32,0.17])
ax0.set_ylabel(r'$1-\mathcal{F}$',fontsize=fs[1])
ax0.set_xlabel(r'Loops', fontsize=fs[1])
ax0.plot(x,1-min1,  lw=2, linestyle='-', color=color[1],alpha=1)
ax0.scatter(x, (1-np.array(evo[0][0])),s=6,alpha=0.2,linewidths=0,color=color[1])
#ax0.hlines(1-np.max(lin[:,3]),-100,1100,ls='--',alpha=0.6,color='k')
ax0.set_xlim([-50,1050])
ax0.yaxis.set_major_locator(MultipleLocator(0.2))
ax0.yaxis.set_minor_locator(MultipleLocator(0.1))
ax0.xaxis.set_major_locator(MultipleLocator(500))
ax0.xaxis.set_minor_locator(MultipleLocator(100))
ax0.tick_params(axis='both', which='major', labelsize=fs[2],length=5,width=1)
ax0.tick_params(axis='both', which='minor', labelsize=fs[2],length=3,width=1)


# ax1.plot(lin[:,1][:]/0.1,lin[:,2][:], '-', lw=2, color=ecl[1], alpha=0.6)
# ax1.plot(lin[:,1][::6+2]/0.1,lin[:,2][::6+2], 'o',mec=ecl[1],mfc=fcl[1],ms=8,alpha=1,label='Linear',mew=1.5)
ax1.plot(opt[:,1][:],opt[:,2][:], '-', lw=2, color=ecl[0], alpha=0.6)
ax1.plot(opt[:,1][::6],opt[:,2][::6], 'o',mec=ecl[0],mfc=fcl[0],ms=8,alpha=0.9,label='QAOA',mew=1.5)


#ax1.set_xticklabels([])
ax1.yaxis.set_major_locator(MultipleLocator(0.5))
ax1.yaxis.set_minor_locator(MultipleLocator(0.1))
ax1.xaxis.set_major_locator(MultipleLocator(2))
ax1.xaxis.set_minor_locator(MultipleLocator(0.5))
ax1.tick_params(axis='both', which='major', labelsize=fs[2],length=5,width=1)
ax1.tick_params(axis='both', which='minor', labelsize=fs[2],length=3,width=1)
ax1.set_ylabel(r'$S_{half}$',fontsize=fs[1])
ax1.set_xlabel(r'Time $/\ J_R$', fontsize=fs[1])
# ax1.legend(fontsize=fs[2])




# ax3.plot(lin[:,1][:]/0.1,lcor[0][:,0][:],color=ecl[1],ls='-',alpha=0.6,lw=1.5)
# ax4.plot(lin[:,1][:]/0.1,lcor[0][:,1][:],color=ecl[1],ls='-',alpha=0.6,lw=1.5)
# ax5.plot(lin[:,1][:]/0.1,lcor[0][:,2][:],color=ecl[1],ls='-',alpha=0.6,lw=1.5)
# ax6.plot(lin[:,1][:]/0.1,lcor[0][:,3][:],color=ecl[1],ls='-',alpha=0.6,lw=1.5)
# ax7.plot(lin[:,1][:]/0.1,lcor[0][:,4][:],color=ecl[1],ls='-',alpha=0.6,lw=1.5)
# ax3.plot(lin[:,1][::6+2]/0.1,lcor[0][:,0][::6+2],'o',mec=ecl[1],mfc=fcl[1],ms=6,alpha=1.0,mew=1.2)
# ax4.plot(lin[:,1][::6+2]/0.1,lcor[0][:,1][::6+2],'o',mec=ecl[1],mfc=fcl[1],ms=6,alpha=1.0,mew=1.2)
# ax5.plot(lin[:,1][::6+2]/0.1,lcor[0][:,2][::6+2],'o',mec=ecl[1],mfc=fcl[1],ms=6,alpha=1.0,mew=1.2)
# ax6.plot(lin[:,1][::6+2]/0.1,lcor[0][:,3][::6+2],'o',mec=ecl[1],mfc=fcl[1],ms=6,alpha=1.0,mew=1.2)
# ax7.plot(lin[:,1][::6+2]/0.1,lcor[0][:,4][::6+2],'o',mec=ecl[1],mfc=fcl[1],ms=6,alpha=1.0,mew=1.2)

ax3.plot(opt[:,1][:], cor[0][:,0][:],color=ecl[1],ls='-',alpha=0.6,lw=1.5)
ax4.plot(opt[:,1][:], cor[0][:,1][:],color=ecl[4],ls='-',alpha=0.6,lw=1.5)
ax5.plot(opt[:,1][:], cor[0][:,2][:],color=ecl[2],ls='-',alpha=0.6,lw=1.5)
ax6.plot(opt[:,1][:], cor[0][:,3][:],color=ecl[0],ls='-',alpha=0.6,lw=1.5)
ax7.plot(opt[:,1][:], cor[0][:,4][:],color=ecl[3],ls='-',alpha=0.6,lw=1.5)
ax3.plot(opt[:,1][::6], cor[0][:,0][::6],'D',mec=ecl[1],mfc=fcl[1],ms=6,alpha=1.0,mew=1.2)
ax4.plot(opt[:,1][::6], cor[0][:,1][::6],'D',mec=ecl[4],mfc=fcl[4],ms=6,alpha=1.0,mew=1.2)
ax5.plot(opt[:,1][::6], cor[0][:,2][::6],'D',mec=ecl[2],mfc=fcl[2],ms=6,alpha=1.0,mew=1.2)
ax6.plot(opt[:,1][::6], cor[0][:,3][::6],'D',mec=ecl[0],mfc=fcl[0],ms=6,alpha=1.0,mew=1.2)
ax7.plot(opt[:,1][::6], cor[0][:,4][::6],'D',mec=ecl[3],mfc=fcl[3],ms=6,alpha=1.0,mew=1.2)




ax3.set_ylim([0.35,0.75])
ax4.set_ylim([-0.05,0.25])
ax5.set_ylim([-0.02,0.18])
ax6.set_ylim([-0.02,0.15])
ax7.set_ylim([-0.02,0.15])

ax5.yaxis.set_major_locator(MultipleLocator(0.1))
ax5.yaxis.set_minor_locator(MultipleLocator(0.025))
ax4.yaxis.set_major_locator(MultipleLocator(0.2))
ax4.yaxis.set_minor_locator(MultipleLocator(0.05))
ax3.text(2,0.68,   r'$d=1$', fontsize=fs[2], ha='center',va='center')
ax4.text(2,0.1975, r'$d=2$', fontsize=fs[2], ha='center',va='center')
ax5.text(2,0.145,r'$d=3$', fontsize=fs[2], ha='center',va='center')
ax6.text(2,0.12025,r'$d=4$', fontsize=fs[2], ha='center',va='center')
ax7.text(2,0.12025,r'$d=5$', fontsize=fs[2], ha='center',va='center')
ax4.set_xticklabels([])
ax5.set_xticklabels([])
ax6.set_xticklabels([])
ax7.set_xticklabels([])
ax3.set_xlabel(r'Time $/\ J_R$', fontsize=fs[1])
ax5.set_ylabel(r'$I_m(d)$', fontsize=fs[1])

ax3.tick_params(axis='both', which='major', labelsize=fs[2],length=5,width=1)
ax4.tick_params(axis='both', which='major', labelsize=fs[2],length=5,width=1)
ax5.tick_params(axis='both', which='major', labelsize=fs[2],length=5,width=1)
ax6.tick_params(axis='both', which='major', labelsize=fs[2],length=5,width=1)
ax7.tick_params(axis='both', which='major', labelsize=fs[2],length=5,width=1)
ax3.tick_params(axis='both', which='minor', labelsize=fs[2],length=3,width=1)
ax4.tick_params(axis='both', which='minor', labelsize=fs[2],length=3,width=1)
ax5.tick_params(axis='both', which='minor', labelsize=fs[2],length=3,width=1)
ax6.tick_params(axis='both', which='minor', labelsize=fs[2],length=3,width=1)
ax7.tick_params(axis='both', which='minor', labelsize=fs[2],length=3,width=1)



plt.savefig('fig5.pdf',dpi=600)
# plt.savefig('../../Draft/fig5.pdf',dpi=600) 
plt.show()

# %% [markdown]
# ## fig6

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import matplotlib.ticker as ticker

import xlrd 
import numpy as np
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import matplotlib.colors as colors
from pdf2image import convert_from_path
from mpl_toolkits.mplot3d import Axes3D  
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
col_width = 3.375 * 2# inch
fs = np.array([10, 7, 5.5])*2 # text, label, tick

upper = mpl.cm.coolwarm(np.arange(256))
lower = np.ones((int(256/4),4))
for i in range(3):
    lower[:,i] = np.linspace(1, upper[0,i], lower.shape[0])
mycmap = np.vstack(( lower, upper ))
mycmap = mpl.colors.ListedColormap(mycmap, name='mycmap', N=mycmap.shape[0])

# %%
from matplotlib.colors import ListedColormap,LinearSegmentedColormap
clist=['w','#096A94']
newcmp = LinearSegmentedColormap.from_list('chaos',clist)
clist=['#8A1A1C','w','#096A94']
newcmp1 = LinearSegmentedColormap.from_list('chaos',clist)

fcl=["#B8D5E2",'#E0B8B8',"#D9D9D9","#BCE5A8"]
ecl=['#096A94','#8A1A1C',"#636363","#31711B"]

# %%
workbook = xlrd.open_workbook('./fig6.xls')
sheet_name = ["440","441","442","443","444"]
Cd44=[]
for name in sheet_name:

    worksheet = workbook.sheet_by_name(name)
    
    offset = -1
    
    cols = []
    for i, row in enumerate(range(worksheet.ncols)):
        if i <= offset:
            continue
        c = []
        for j, row in enumerate(range(worksheet.nrows)):
            c.append(worksheet.cell_value(j, i))
        cols.append(c)
    
    for col in cols:
        u = 1
        for j in range(len(col)):
            if '' in col: 
                col.remove('') 
            if '--' in col: 
                col.remove('--') 
    Cd44.append(cols)
worksheet = workbook.sheet_by_name("zzzz")    
offset = -1    
cols = []
for i, row in enumerate(range(worksheet.ncols)):
    if i <= offset:
        continue
    c = []
    for j, row in enumerate(range(worksheet.nrows)):
        c.append(worksheet.cell_value(j, i))
    cols.append(c)  
for col in cols:
    u = 1
    for j in range(len(col)):
        if '' in col: 
            col.remove('') 
        if '--' in col: 
            col.remove('--') 
zzzz=np.mat(cols)

worksheet = workbook.sheet_by_name("Icorner")    
offset = -1    
cols = []
for i, row in enumerate(range(worksheet.ncols)):
    if i <= offset:
        continue
    c = []
    for j, row in enumerate(range(worksheet.nrows)):
        c.append(worksheet.cell_value(j, i))
    cols.append(c)  
for col in cols:
    u = 1
    for j in range(len(col)):
        if '' in col: 
            col.remove('') 
        if '--' in col: 
            col.remove('--') 
Icorner=cols

worksheet = workbook.sheet_by_name("rob")    
offset = -1    
cols = []
for i, row in enumerate(range(worksheet.ncols)):
    if i <= offset:
        continue
    c = []
    for j, row in enumerate(range(worksheet.nrows)):
        c.append(worksheet.cell_value(j, i))
    cols.append(c)  
for col in cols:
    u = 1
    for j in range(len(col)):
        if '' in col: 
            col.remove('') 
        if '--' in col: 
            col.remove('--') 
rob=cols


worksheet = workbook.sheet_by_name("en")    
offset = -1    
cols = []
for i, row in enumerate(range(worksheet.ncols)):
    if i <= offset:
        continue
    c = []
    for j, row in enumerate(range(worksheet.nrows)):
        c.append(worksheet.cell_value(j, i))
    cols.append(c)  
for col in cols:
    u = 1
    for j in range(len(col)):
        if '' in col: 
            col.remove('') 
        if '--' in col: 
            col.remove('--') 
en=np.mat(cols)

# %%
plt.style.use(['science'])

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "sans-serif",   # specify font family here
    "font.sans-serif": "Arial",
    "mathtext.fontset":"stixsans",
    "font.size":11,
    "savefig.bbox": "standard",
    'xtick.top': False,
    'ytick.right': False,
    'xtick.direction':'in',
    'ytick.direction':'out',
     'axes.linewidth':1,
    }) 


fig = plt.figure(figsize=[col_width*2, col_width*0.8], 
                 facecolor='None') 



# fig.text(0.020, 0.96, r'b', size=fs[0])
# fig.text(0.020, 0.76, r'c', size=fs[0])
# fig.text(0.020, 0.55, r'd', size=fs[0])
# fig.text(0.020, 0.37, r'e', size=fs[0])

plt.rcParams.update({
    "text.usetex": False,
    "font.family": "sans-serif",# specify font family here
    "font.sans-serif": "Helvetica Neue",
    "mathtext.fontset":"stixsans",
    "font.size":11,
    "savefig.bbox": "standard",
    'xtick.top': False,
    'ytick.right': False,
    'xtick.direction':'in',
    'ytick.direction':'out',
    }) 

# ax00= fig.add_axes([0.085,0.66,0.88,0.4])
ax2 = fig.add_axes([0.44, 0.74, 0.08,0.2])
ax3 = fig.add_axes([0.44, 0.52, 0.08,0.2])
ax4 = fig.add_axes([0.44, 0.3, 0.08,0.2])
ax5 = fig.add_axes([0.44, 0.08, 0.08,0.2])


ax1 = fig.add_axes([0.72,0.52,0.26,0.42])
tax1 = fig.add_axes([0.72,0.08,0.26,0.42])

ax8 = fig.add_axes([0.53, 0.72, 0.15,0.28],xlim=[4,11], ylim=[4,11],zlim=[0,0.6],projection = "3d")
ax9 = fig.add_axes([0.53, 0.50, 0.15,0.28],xlim=[4,11], ylim=[4,11],zlim=[0,0.6],projection = "3d")
ax10= fig.add_axes([0.53, 0.28, 0.15,0.28],xlim=[4,11], ylim=[4,11],zlim=[0,0.6],projection = "3d")
ax7 = fig.add_axes([0.53, 0.06 , 0.15,0.28],xlim=[4,11], ylim=[4,11],zlim=[0,0.6],projection = "3d")

### (b)



# img = convert_from_path('fig8c.pdf',dpi=600)
# ax00.imshow(img[0],zorder=10)
# ax00.axis('off')


xm,ym = np.meshgrid(np.linspace(-3.5,3.5,8),
                    np.linspace(-3.5,3.5,8))

for j,caxis,cs in zip([1,2,3,4],
                      [ax2,ax3,ax4,ax5],
                      [r'i',r'ii',r'iii',r'iv']):
    img = caxis.pcolormesh(xm,ym,np.array(Cd44[j]),
                           cmap=newcmp,
                           shading='flat',
                           linewidth=0,
                           vmin=0,
                           vmax=np.log(2),
                           zorder=0)
    caxis.text(-2.5, 2.5, cs,
               fontsize=fs[2],
               ha="center", 
               va="center",
               bbox = dict(boxstyle=f"circle, pad={0.10}",fc="w",lw=0.75,alpha=1),zorder=20)

    caxis.set_ylim([-3.5,3.5])
    caxis.set_xlim([-3.5,3.5])
        
    caxis.yaxis.set_major_locator(MultipleLocator(3))
    caxis.yaxis.set_minor_locator(MultipleLocator(1))
    caxis.xaxis.set_major_locator(MultipleLocator(3))
    caxis.xaxis.set_minor_locator(MultipleLocator(1))
    caxis.set_xticklabels([])
    caxis.set_yticklabels([])
    caxis.tick_params(axis='both', which='major', labelsize=fs[2],length=5,width=1)
    caxis.tick_params(axis='both', which='minor', labelsize=fs[2],length=3,width=1)
    caxis.tick_params(axis='y', which='major', direction='in')
    caxis.tick_params(axis='y', which='minor', direction='in')

fig.text(0.42,0.50,r'$d_y$ (sites)',fontsize=fs[1],ha='center',va='center',rotation=90)
ax5.set_xlabel(r'$d_x$ (sites)',fontsize=fs[1])
ax5.set_xticks([-3,0,3])
#ax5.set_xticklabels([-3,0,3])

ax2.text(-6.2,0,r'$\mathrm{I(\mathbf{d})}$', size=fs[1], va="center",ha="center")
clevs = [0,np.log(2)]
cax1 = inset_axes(ax2,width='10%',height='100%',
                 bbox_to_anchor=[-0.98,0.07,1,1],
                 bbox_transform=ax2.transAxes)
cbar=plt.colorbar(img, cax=cax1,ticks=clevs,location='left')
cbar.set_ticklabels(['0',r'$ln(2)$'])
cax1.tick_params(axis='both', which='major', labelsize=fs[2])




color='#096A93'#B91F33'
ax1.plot(np.logspace(-1,2,7),Icorner[2:], '-', lw=2.0, color=ecl[0],alpha=0.5)
ax1.plot(np.logspace(-1,2,7),Icorner[2:], 'o', mew=1.2, mec=ecl[0],mfc=fcl[0], ms=8, alpha=1.0)
ax1.vlines([0.1,1,10,100],-0.1,1.1,linestyle=(0,(4,2)),lw=1,color='gray',alpha=0.5,zorder=2)
ax1.set_ylabel(r'$I_{corner}$',fontsize=fs[1],color=color)
ax1.set_xlim([0.08,120])
ax1.set_ylim([-0.05,1.05])
ax1.yaxis.set_major_locator(MultipleLocator(0.4))
ax1.yaxis.set_minor_locator(MultipleLocator(0.1))
ax1.set_xscale('log')
ax1.set_xticks([])
ax1.set_xticklabels([])
ax1.tick_params(axis='both', which='major', labelsize=fs[2],top=False,length=5,width=1)
ax1.tick_params(axis='both', which='minor', labelsize=fs[2],top=False,length=3,width=1)
# ax1.spines['top'].set_visible(False)
# ax1.spines['right'].set_visible(False)


color='#891A1C'#3C658D
tax1.plot(np.logspace(-1,2,7),np.array(zzzz)[2:], '-', lw=2.0, color=ecl[1],alpha=0.5)
tax1.plot(np.logspace(-1,2,7),np.array(zzzz)[2:], 'o',  mew=1.2, mec=ecl[1],mfc=fcl[1], ms=8, alpha=1.0)
tax1.vlines([0.1,1,10,100],-0.3,1.1,linestyle=(0,(4,2)),lw=1,color='gray',alpha=0.7,zorder=2)

tax1.set_ylabel(r'$\langle \hat{\sigma^z}\hat{\sigma^z}\hat{\sigma^z}\hat{\sigma^z}\rangle$',fontsize=fs[1],color=color)
tax1.set_xscale('log')
tax1.set_xlim([0.08,120])
tax1.set_xticks([0.1,1,10,100])
tax1.set_xticklabels([0.1,1,10,100])
tax1.set_ylim([-0.06,1.06])
tax1.yaxis.set_major_locator(MultipleLocator(0.5))
tax1.yaxis.set_minor_locator(MultipleLocator(0.1))
tax1.tick_params(axis='both', which='major', labelsize=fs[2],top=False,length=5,width=1)
tax1.tick_params(axis='both', which='minor', labelsize=fs[2],top=False,length=3,width=1)
tax1.set_xlabel(r'$J_2/J_0$ ', fontsize=fs[1])
# tax1.spines['top'].set_visible(False)
# tax1.spines['right'].set_visible(False)




for cx,cs in zip([0.1,1.0,10,100],
                 [r'i',r'ii',r'iii',r'iv']):
    ax1.text(cx,0.95, cs,
             fontsize=fs[2],
             ha="center", 
             va="center",
             bbox = dict(boxstyle=f"circle, pad={0.10}",fc="w",lw=0.75,alpha=1),zorder=20)





lw=0.2
artists = ax8.findobj(match = Poly3DCollection)
for obj in artists:
    obj.remove()    
_x = np.arange(16)
_y = np.arange(16)
_xx, _yy = np.meshgrid(_x, _y)
x, y = _xx.ravel(), _yy.ravel()
zz=rob[1]
bottom = np.zeros_like(zz)
# Construct arrays with the dimensions for the 16 bars.
dx = dy = 1

ax8.xaxis.set_major_locator(MultipleLocator(16))
ax8.xaxis.set_minor_locator(MultipleLocator(16))
ax8.yaxis.set_major_locator(MultipleLocator(16))
ax8.yaxis.set_minor_locator(MultipleLocator(16))

#ax7.bar3d(x, y, bottom, dx, dy, zz, shade=True,alpha=0.5)

for i in range(4, 12):
    for j in range(4, 12):
        z = zz[i*16+j] #该柱的高
        if (i ==6) & (j == 6):
            color = '#096A93'
            alpha=0.4
        elif (i ==6) & (j == 9):
            color = '#096A93'
            alpha=0.4
        elif (i ==9) & (j == 6):
            color = '#096A93'
            alpha=0.4
        elif (i ==9) & (j == 9):
            color = '#096A93'
            alpha=0.4
        else:
            color='w'
            alpha=0.1
        ax8.bar3d(i, 15-j, 0, dx, dy, z,color=color,edgecolor=ecl[2],lw=lw,shade=True,alpha=alpha) #每次画一个柱




ax8.azim = 210#200  # z rotation (default=270)
ax8.elev = 25#15     # x rotation (default=0)
ax8.set_facecolor("None")    
ax8.set_xlim([4,12]) 
ax8.set_ylim([4,12]) 
ax8.set_zlim([0,0.1])    
ax8.set_xticks([6.5,9.5])
ax8.set_xticklabels([])
ax8.set_yticks([6.5,9.5])
ax8.set_yticklabels([])
ax8.set_zticks([0.1])
ax8.set_zticklabels([0.1])
ax8.zaxis.set_major_locator(MultipleLocator(0.1))
ax8.zaxis.set_minor_locator(MultipleLocator(0.02))
ax8.get_proj = lambda: np.dot(Axes3D.get_proj(ax7), np.diag([0.9, 0.9, 5, 1.1]))
ax8.tick_params(axis='both', which='major', labelsize=fs[2],top=False)
ax8.tick_params(axis='x',pad=-2)
ax8.tick_params(axis='y',pad=-2)
ax8.tick_params(axis='z',pad=-1)
ax8.plot([8,8,8],[2.9,3.3,3.7],[0.0,0.0,0.0],'.',ms=2,color='k',alpha=1,zorder=20)
ax8.plot([2.3,3.0,3.7],[8,8,8],[0.0,0.0,0.0],'.',ms=2,color='k',alpha=1,zorder=20)
ax8.text(5    ,2.8   ,0,r'$1010$',fontsize=fs[2])
ax8.text(8.2    ,2.5   ,0,r'$0101$',fontsize=fs[2])
ax8.text(0.3,6.5 ,0,r'$0101$',fontsize=fs[2])
ax8.text(0.3,11.0,0,r'$1010$',fontsize=fs[2])




artists = ax9.findobj(match = Poly3DCollection)
for obj in artists:
    obj.remove()    
_x = np.arange(16)
_y = np.arange(16)
_xx, _yy = np.meshgrid(_x, _y)
x, y = _xx.ravel(), _yy.ravel()
zz=rob[2]
bottom = np.zeros_like(zz)
# Construct arrays with the dimensions for the 16 bars.
dx = dy = 1

ax9.xaxis.set_major_locator(MultipleLocator(16))
ax9.xaxis.set_minor_locator(MultipleLocator(16))
ax9.yaxis.set_major_locator(MultipleLocator(16))
ax9.yaxis.set_minor_locator(MultipleLocator(16))

#ax7.bar3d(x, y, bottom, dx, dy, zz, shade=True,alpha=0.5)

for i in range(4, 12):
    for j in range(4, 12):
        z = zz[i*16+j] #该柱的高
        if (i ==6) & (j == 6):
            color = '#096A93'
            alpha=0.4
        elif (i ==6) & (j == 9):
            color = '#096A93'
            alpha=0.4
        elif (i ==9) & (j == 6):
            color = '#096A93'
            alpha=0.4
        elif (i ==9) & (j == 9):
            color = '#096A93'
            alpha=0.4
        else:
            color='w'
            alpha=0.1
        ax9.bar3d(i, 15-j, 0, dx, dy, z,color=color,edgecolor=ecl[2],lw=lw,shade=True,alpha=alpha) #每次画一个柱




ax9.azim = 210#200  # z rotation (default=270)
ax9.elev = 25#15     # x rotation (default=0)
ax9.set_facecolor("None")    
ax9.set_xlim([4,12]) 
ax9.set_ylim([4,12]) 
ax9.set_zlim([0,0.1])    
ax9.set_xticks([6.5,9.5])
ax9.set_xticklabels([])
ax9.set_yticks([6.5,9.5])
ax9.set_yticklabels([])
ax9.set_zticks([0.1])
ax9.set_zticklabels([0.1])
ax9.zaxis.set_major_locator(MultipleLocator(0.1))
ax9.zaxis.set_minor_locator(MultipleLocator(0.02))
ax9.get_proj = lambda: np.dot(Axes3D.get_proj(ax7), np.diag([0.9, 0.9, 5, 1.1]))
ax9.tick_params(axis='both', which='major', labelsize=fs[2],top=False)
ax9.tick_params(axis='x',pad=-2)
ax9.tick_params(axis='y',pad=-2)
ax9.tick_params(axis='z',pad=-1)
ax9.plot([8,8,8],[2.9,3.3,3.7],[0.0,0.0,0.0],'.',ms=2,color='k',alpha=1,zorder=20)
ax9.plot([2.3,3.0,3.7],[8,8,8],[0.0,0.0,0.0],'.',ms=2,color='k',alpha=1,zorder=20)
ax9.text(5    ,2.8   ,0,r'$1010$',fontsize=fs[2])
ax9.text(8.2    ,2.5   ,0,r'$0101$',fontsize=fs[2])
ax9.text(0.3,6.5 ,0,r'$0101$',fontsize=fs[2])
ax9.text(0.3,11.0,0,r'$1010$',fontsize=fs[2])




artists = ax10.findobj(match = Poly3DCollection)
for obj in artists:
    obj.remove()    
_x = np.arange(16)
_y = np.arange(16)
_xx, _yy = np.meshgrid(_x, _y)
x, y = _xx.ravel(), _yy.ravel()
zz=rob[3]
bottom = np.zeros_like(zz)
# Construct arrays with the dimensions for the 16 bars.
dx = dy = 1

ax10.xaxis.set_major_locator(MultipleLocator(16))
ax10.xaxis.set_minor_locator(MultipleLocator(16))
ax10.yaxis.set_major_locator(MultipleLocator(16))
ax10.yaxis.set_minor_locator(MultipleLocator(16))

#ax7.bar3d(x, y, bottom, dx, dy, zz, shade=True,alpha=0.5)

for i in range(4, 12):
    for j in range(4, 12):
        z = zz[i*16+j] #该柱的高
        if (i ==6) & (j == 6):
            color = '#096A93'
            alpha=0.4
        elif (i ==6) & (j == 9):
            color = '#096A93'
            alpha=0.4
        elif (i ==9) & (j == 6):
            color = '#096A93'
            alpha=0.4
        elif (i ==9) & (j == 9):
            color = '#096A93'
            alpha=0.4
        else:
            color='w'
            alpha=0.1
        ax10.bar3d(i, 15-j, 0, dx, dy, z,color=color,edgecolor=ecl[2],lw=lw,shade=True,alpha=alpha) #每次画一个柱



ax10.azim = 210#200  # z rotation (default=270)
ax10.elev = 25#15     # x rotation (default=0)
ax10.set_facecolor("None")    
ax10.set_xlim([4,12]) 
ax10.set_ylim([4,12]) 
ax10.set_zlim([0,0.5])    
ax10.set_xticks([6.5,9.5])
ax10.set_xticklabels([])
ax10.set_yticks([6.5,9.5])
ax10.set_yticklabels([])
ax10.set_zticks([0.5])
ax10.set_zticklabels([0.5])
ax10.zaxis.set_major_locator(MultipleLocator(0.5))
ax10.zaxis.set_minor_locator(MultipleLocator(0.1))
ax10.get_proj = lambda: np.dot(Axes3D.get_proj(ax7), np.diag([0.9, 0.9, 1.0, 1.1]))
ax10.tick_params(axis='both', which='major', labelsize=fs[2],top=False)
ax10.tick_params(axis='x',pad=-2)
ax10.tick_params(axis='y',pad=-2)
ax10.tick_params(axis='z',pad=-1)
ax10.plot([8,8,8],[2.9,3.3,3.7],[0.0,0.0,0.0],'.',ms=2,color='k',alpha=1,zorder=20)
ax10.plot([2.3,3.0,3.7],[8,8,8],[0.0,0.0,0.0],'.',ms=2,color='k',alpha=1,zorder=20)
ax10.text(5    ,2.8   ,0,r'$1010$',fontsize=fs[2])
ax10.text(8.2    ,2.5   ,0,r'$0101$',fontsize=fs[2])
ax10.text(0.3,6.5 ,0,r'$0101$',fontsize=fs[2])
ax10.text(0.3,11.0,0,r'$1010$',fontsize=fs[2])



artists = ax7.findobj(match = Poly3DCollection)
for obj in artists:
    obj.remove()    
_x = np.arange(16)
_y = np.arange(16)
_xx, _yy = np.meshgrid(_x, _y)
x, y = _xx.ravel(), _yy.ravel()
zz=rob[-1]
bottom = np.zeros_like(zz)
# Construct arrays with the dimensions for the 16 bars.
dx = dy = 1

ax7.xaxis.set_major_locator(MultipleLocator(16))
ax7.xaxis.set_minor_locator(MultipleLocator(16))
ax7.yaxis.set_major_locator(MultipleLocator(16))
ax7.yaxis.set_minor_locator(MultipleLocator(16))

#ax7.bar3d(x, y, bottom, dx, dy, zz, shade=True,alpha=0.5)

for i in range(4, 12):
    for j in range(4, 12):
        z = zz[i*16+j] #该柱的高
        if (i ==6) & (j == 6):
            color = '#096A93'
            alpha=0.4
        elif (i ==6) & (j == 9):
            color = '#096A93'
            alpha=0.4
        elif (i ==9) & (j == 6):
            color = '#096A93'
            alpha=0.4
        elif (i ==9) & (j == 9):
            color = '#096A93'
            alpha=0.4
        else:
            color='w'
            alpha=1
        ax7.bar3d(j, i, 0, dx, dy, z,color=color,edgecolor=ecl[2],lw=lw,shade=True,alpha=alpha) #每次画一个柱



ax7.azim = 210#200  # z rotation (default=270)
ax7.elev = 25#15     # x rotation (default=0)
ax7.set_facecolor("None")    
ax7.set_xlim([4,12]) 
ax7.set_ylim([4,12]) 
ax7.set_zlim([0,0.5])    
ax7.set_xticks([6.5,9.5])
ax7.set_xticklabels([])
ax7.set_yticks([6.5,9.5])
ax7.set_yticklabels([])
ax7.set_zticks([0.5])
ax7.set_zticklabels([0.5])
ax7.zaxis.set_major_locator(MultipleLocator(0.5))
ax7.zaxis.set_minor_locator(MultipleLocator(0.1))
ax7.get_proj = lambda: np.dot(Axes3D.get_proj(ax7), np.diag([0.9, 0.9, 1.0, 1.1]))
ax7.tick_params(axis='both', which='major', labelsize=fs[2],top=False)
ax7.tick_params(axis='x',pad=-2)
ax7.tick_params(axis='y',pad=-2)
ax7.tick_params(axis='z',pad=-1)
ax7.plot([8,8,8],[2.9,3.3,3.7],[0.0,0.0,0.0],'.',ms=2,color='k',alpha=1,zorder=20)
ax7.plot([2.3,3.0,3.7],[8,8,8],[0.0,0.0,0.0],'.',ms=2,color='k',alpha=1,zorder=20)
ax7.text(5    ,2.8   ,0,r'$1010$',fontsize=fs[2])
ax7.text(8.2    ,2.5   ,0,r'$0101$',fontsize=fs[2])
ax7.text(0.3,6.5 ,0,r'$0101$',fontsize=fs[2])
ax7.text(0.3,11.0,0,r'$1010$',fontsize=fs[2])


fig.text(0.58, 0.96, r'$\rho_{corner}$', size=fs[1])

ax0 = fig.add_axes([0.05,0.08,0.3,0.3])
#xm, ym = np.meshgrid(np.linspace(-0.5,100.5,102),np.linspace(-0.05,2.05,22))
xm, ym = np.meshgrid(np.linspace(-2.5,102.5,22),np.linspace(-0.05,2.05,22))

img=ax0.pcolormesh(xm,ym,en[::5,:].T,cmap=newcmp1,shading='flat',norm=colors.LogNorm(vmin=1e-6, vmax=np.max(en)))
# ax0.set_xscale('log')
ax0.set_xlim([-2.5,102.5])
ax0.set_ylim([-0.05,1.35])
# ax0.yaxis.set_major_locator(MultipleLocator(0.5))
# ax0.yaxis.set_minor_locator(MultipleLocator(0.1))
# ax0.xaxis.set_major_locator(MultipleLocator(2))
# ax0.xaxis.set_minor_locator(MultipleLocator(1))
ax0.tick_params(axis='both', which='major', labelsize=fs[2],length=5,width=1)
ax0.tick_params(axis='both', which='minor', labelsize=fs[2],length=3,width=1)
ax0.set_xlabel(r'$J_2/J_0$',fontsize=fs[1])
ax0.set_ylabel(r'$J_1/J_0$', fontsize=fs[1])
ax0.text(114,0.65,r'$\Delta_g\ /\ J_0$', size=fs[1], va="center",ha="center",rotation=90)
clevs = [1e-6,1]
cax1 = inset_axes(ax0,width='3%',height='100%',
                 bbox_to_anchor=[0.07,0.05,1,1],
                 bbox_transform=ax0.transAxes)
cbar=plt.colorbar(img, cax=cax1,ticks=clevs)
cbar.set_ticklabels(['1e-6','1'])
cax1.tick_params(axis='both', which='major', labelsize=fs[2])

# ax0.text(8, 0.6, r'i',
#                fontsize=fs[2],
#                ha="left", 
#                va="center",
#                bbox = dict(boxstyle=f"circle, pad={0.10}",fc="w",lw=0.75,alpha=1),zorder=20)

# ax0.text(4, 1.7, r'ii',
#                fontsize=fs[2],
#                ha="left", 
#                va="center",
#                bbox = dict(boxstyle=f"circle, pad={0.10}",fc="w",lw=0.75,alpha=1),zorder=20)

# ax0.text(30, 1.7, r'iii',
#                fontsize=fs[2],
#                ha="left", 
#                va="center",
#                bbox = dict(boxstyle=f"circle, pad={0.10}",fc="w",lw=0.75,alpha=1),zorder=20)

# ax0.text(56, 1.7, r'iv',
#                fontsize=fs[2],
#                ha="left", 
#                va="center",
#                bbox = dict(boxstyle=f"circle, pad={0.10}",fc="w",lw=0.75,alpha=1),zorder=20)

# ax0.text(82, 1.7, r'v',
#                fontsize=fs[2],
#                ha="left", 
#                va="center",
#                bbox = dict(boxstyle=f"circle, pad={0.10}",fc="w",lw=0.75,alpha=1),zorder=20)

# ax0.annotate("", 
#              xy=(1.5, 0.9), 
#              xytext=(1.5, 0.15),
#              arrowprops=dict(arrowstyle="->"))

# ax0.annotate("", 
#              xy=(94.5, 1.0), 
#              xytext=(15, 1.0),
#              arrowprops=dict(arrowstyle="->"))


plt.savefig('fig6-1.pdf',dpi=600)
# plt.savefig('../../Draft/fig6-1.pdf',dpi=600)



plt.show()
